# %% [markdown]
# # Imports

# %%
import pandas as pd
from unidecode import unidecode
from datetime import datetime

# %% [markdown]
# # Load Data

# %%
df_gupy = pd.read_excel('../data/data_raw/vagas_gupy_raw.xlsx')

df_vagas = pd.concat([df_gupy], axis = 0)
df_vagas.head()
# Out:
#   site_da_vaga                                          link_site  \
# 0         Gupy  https://franquiasv4.gupy.io/job/eyJqb2JJZCI6Nj...
# 1         Gupy  https://neoassist.gupy.io/job/eyJqb2JJZCI6Njcx...
# 2         Gupy  https://mesha.gupy.io/job/eyJqb2JJZCI6NjcwOTgx...
# 3         Gupy  https://mesha.gupy.io/job/eyJqb2JJZCI6NjcwOTMz...
# 4         Gupy  https://vemserolxbrasil.gupy.io/job/eyJqb2JJZC...
#
#                                          link_origem  \
# 0  https://franquiasv4.gupy.io/job/eyJqb2JJZCI6Nj...
# 1  https://neoassist.gupy.io/job/eyJqb2JJZCI6Njcx...
# 2  https://mesha.gupy.io/job/eyJqb2JJZCI6NjcwOTgx...
# 3  https://mesha.gupy.io/job/eyJqb2JJZCI6NjcwOTMz...
# 4  https://vemserolxbrasil.gupy.io/job/eyJqb2JJZC...
#
#             data_publicacao data_expiracao data_coleta            posicao  \
# 0  Publicada em: 03/02/2024     2024-03-01  2024-02-05  Analista de Dados
# 1  Publicada em: 02/02/2024     2024-04-01  2024-02-05  Analista de Dados
# 2  Publicada em: 02/02/2024     2024-04-30  2024-02-05  Analista de Dados
# 3  Publicada em: 02/02/2024     2024-03-31  2024-02-05  Analista de Dados
# 4  Publicada em: 02/02/2024     2024-03-18  2024-02-05  Analista de Dados
#
#                                       titulo_da_vaga           local  \
# 0   Analista de Dados - Junior/Pleno | V4 Jasson ...   Curitiba - PR
# 1                            Analista de Dados Pleno  São Paulo - SP
# 2  Analista de Dados - Trainne (Presencial - Maceió)     Maceió - AL
# 3                         Analista de Dados - Remota   Não informado
# 4                            Analista de Dados Pleno   Não informado
#
#    modalidade         nome_empresa         contrato  regime            pcd  \
# 0     Híbrido  Unidades V4 Company  Pessoa Jurídica     NaN  Também p/ PcD
# 1     Híbrido            NeoAssist          Efetivo     NaN  Também p/ PcD
# 2  Presencial     MESHA TECNOLOGIA          Efetivo     NaN  Também p/ PcD
# 3      Remoto     MESHA TECNOLOGIA          Efetivo     NaN  Também p/ PcD
# 4      Remoto            Grupo OLX          Efetivo     NaN  Também p/ PcD
#
#    beneficios  codigo_vaga                                          descricao
# 0         NaN    6711345.0  Descrição da vagaVenha se juntar com a gente n...
# 1         NaN    6710537.0  Descrição da vagaA Neo está buscando uma pesso...
# 2         NaN    6709810.0  Descrição da vagaCom mais de 12 anos no mercad...
# 3         NaN    6709335.0  Descrição da vagaCom mais de 12 anos no mercad...
# 4         NaN    6609585.0  Descrição da vagaQuer fazer parte de uma das m...

# %% [markdown]
# # Tratamento dos Dados

# %%
df_vagas.dtypes
# Out:
# site_da_vaga        object
# link_site           object
# link_origem         object
# data_publicacao     object
# data_expiracao      object
# data_coleta         object
# posicao             object
# titulo_da_vaga      object
# local               object
# modalidade          object
# nome_empresa        object
# contrato            object
# regime             float64
# pcd                 object
# beneficios         float64
# codigo_vaga        float64
# descricao           object
# dtype: object

# %%
df_vagas.head(1).T
# Out:
#                                                                  0
# site_da_vaga                                                  Gupy
# link_site        https://franquiasv4.gupy.io/job/eyJqb2JJZCI6Nj...
# link_origem      https://franquiasv4.gupy.io/job/eyJqb2JJZCI6Nj...
# data_publicacao                           Publicada em: 03/02/2024
# data_expiracao                                          2024-03-01
# data_coleta                                             2024-02-05
# posicao                                          Analista de Dados
# titulo_da_vaga    Analista de Dados - Junior/Pleno | V4 Jasson ...
# local                                                Curitiba - PR
# modalidade                                                 Híbrido
# nome_empresa                                   Unidades V4 Company
# contrato                                           Pessoa Jurídica
# regime                                                         NaN
# pcd                                                  Também p/ PcD
# beneficios                                                     NaN
# codigo_vaga                                              6711345.0
# descricao        Descrição da vagaVenha se juntar com a gente n...

# %%
df_vagas['data_publicacao'] = df_vagas['data_publicacao'].apply(lambda x: datetime.strptime(x.replace('Publicada em: ', '').replace('/', '-'),'%d-%m-%Y').strftime('%Y-%m-%d'))
df_vagas['data_coleta'] = df_vagas['data_coleta']
df_vagas['pcd'] = df_vagas['pcd'].apply(lambda x: 'Sim' if x == 'Também p/ PcD' else 'Não informado')

# %%
df_vagas.head(1).T
# Out:
#                                                                  0
# site_da_vaga                                                  Gupy
# link_site        https://franquiasv4.gupy.io/job/eyJqb2JJZCI6Nj...
# link_origem      https://franquiasv4.gupy.io/job/eyJqb2JJZCI6Nj...
# data_publicacao                                         2024-02-03
# data_expiracao                                          2024-03-01
# data_coleta                                             2024-02-05
# posicao                                          Analista de Dados
# titulo_da_vaga    Analista de Dados - Junior/Pleno | V4 Jasson ...
# local                                                Curitiba - PR
# modalidade                                                 Híbrido
# nome_empresa                                   Unidades V4 Company
# contrato                                           Pessoa Jurídica
# regime                                                         NaN
# pcd                                                            Sim
# beneficios                                                     NaN
# codigo_vaga                                              6711345.0
# descricao        Descrição da vagaVenha se juntar com a gente n...

# %% [markdown]
# # Features

# %% [markdown]
# ## Senioridade

# %%
# matches para as senioridades
junior_matches = ['junior', ' jr'  , ' i', ' l ']
pleno_matches = ['pleno', ' pl', ' ii', ' ll ']
senior_matches = ['senior', ' sr', ' iii', ' lll ']

# removendo acentos e deixando letras minúsculas
df_vagas['titulo_da_vaga_tratado'] = df_vagas['titulo_da_vaga'].apply(lambda x: unidecode(x.lower()))

# função de faz matches com as senioridades das vagas
def busca_senioridade(titulo_vaga, match_list):
    senioridade = False
    for sub_string in match_list:
        if sub_string in titulo_vaga:
            senioridade = True
    
    return senioridade

# aplicando função
df_vagas['senioridade_junior'] = df_vagas['titulo_da_vaga_tratado'].apply(lambda titulo_vaga: busca_senioridade(titulo_vaga, junior_matches))
df_vagas['senioridade_pleno'] = df_vagas['titulo_da_vaga_tratado'].apply(lambda titulo_vaga: busca_senioridade(titulo_vaga, pleno_matches))
df_vagas['senioridade_senior'] = df_vagas['titulo_da_vaga_tratado'].apply(lambda titulo_vaga: busca_senioridade(titulo_vaga, senior_matches))

# categorizando senioridades
df_vagas['senioridade'] = df_vagas[['senioridade_junior', 
                                    'senioridade_pleno', 
                                    'senioridade_senior']].apply(lambda x:  'Pleno/Sênior' if (x['senioridade_pleno']) and (x['senioridade_senior']) else
                                                                            'Júnior/Pleno' if (x['senioridade_junior']) and (x['senioridade_pleno']) else
                                                                            'Júnior' if x['senioridade_junior'] else 
                                                                            'Pleno' if x['senioridade_pleno'] else
                                                                            'Sênior' if x['senioridade_senior'] else
                                                                            'Não informado'
                                                                            , axis = 1)

# %%
df_vagas.loc[df_vagas['senioridade'] == 'Não informado', 'titulo_da_vaga_tratado'].unique()
# Out:
# array(['analista de dados - trainne (presencial - maceio)',
#        'analista de dados - remota',
#        'processo seletivo 2024.1 - analista de ciencia de dados',
#        ' analista de dados - rio de janeiro/rj',
#        'analista de dados | cresol confederacao', 'analista de dados ',
#        'analista de dados', 'pessoa analista de dados ll',
#        'analista de dados (foco em backstock)',
#        'analista de dados controladoria - canoas ou lajeado/rs',
#        'analista de dados - fortbras - sao paulo/sp',
#        'analista de qualidade de dados ',
#        'analista de dados - contas a receber',
#        'analista de dados (e-commerce)', 'analista de dados - crm - bi',
#        'cas | analista de dados - foco em gestao de comunidade de dados',
#        'analista de dados - geoprocessamento | manufacturing.',
#        'analista de dados (remoto)', 'analista de dados | salvador',
#        'analista de dados | mercado ',
#        'analista de sistemas / engenheiro de dados',
#        'analista de privacidade de dados (lgpd) - presencial brasilia',
#        'analista de customer service - dados | ribas do rio pardo/ms',
#        'logistica: analista de dados', 'analista de dados - comercial   ',
#        'analista de dados - jundiai/sp ', 'analista dados ti',
#        'analista de dados comerciais direcionados a vendas',
#        'analista contabil - analista de dados ',
#        'analista de dados | lapa de baixo/sp | afirmativa pessoas com deficiencia',
#        'cas | analista de dados - foco em associacao e contas',
#        'pessoa analista de dados (cs/cx)', 'analista de dados csc',
#        'analista de dados | data analyst',
#        'analista de dados e politicas publicas - sp ou mg',
#        'analista de dados bi - corporativo',
#        'analista de produtos de dados',
#        'programador / analista de dados - natal/rn',
#        'analista de processos (dados) | guarulhos / sp',
#        'analista financeiro - analise de dados',
#        'analista de ti (plataforma de dados)',
#        'analista de dados gerenciais',
#        'analista de dados | v4 nunes & co.',
#        'analista de dados - pricing ', 'analista de dados e bi ',
#        'pessoa analista engenheira de dados l',
#        'analista de dados - etl/power center - df',
#        'analista de dados (engenheiro)', 'analista de dados - macae/rj',
#        'analista de dados - power bi', 'analista de dados - dashboards',
#        'analista de banco de dados', 'analista banco de dados ',
#        'analista de banco de dados | dbdevops ',
#        '0726 -  analista de dados -  sede administrativa, palotina/pr ',
#        'banco de talentos - analista de dados',
#        'banco de talentos | analista de dados freelancers ',
#        'analista de dados - home office   ',
#        'banco de talentos - analista de dados/ analista de bi ou cientista de dados',
#        'processo seletivo 2024.1 - engenheiro(a) de dados',
#        'pessoa engenheira de dados com python ',
#        'engenheiro de dados trainee  (campina grande)',
#        'pessoa engenheira de dados',
#        'engenheiro de migracao de dados (chapeco-sc)',
#        'engenheiro(a) de dados ',
#        'pessoa engenheira de dados (cosmos, spark, databricks)',
#        'engenheiro de dados',
#        'visagio talentos - formados: engenheiro(a) de dados [remoto / hibrido]',
#        'engenheiro de dados - data & analytics',
#        'visagio talentos - estagio: engenheiro(a) de dados [remoto / hibrido]',
#        'engenheira(o) de dados especialista',
#        '14294-pessoa engenheira de dados',
#        'engenheiro(a) de dados t.i | ramo seguros e beneficios | sao paulo - sp',
#        'engenheiro(a) de dados - presencial (maceio)',
#        'engenheiro de dados | data engineer',
#        'especialista engenheiro de dados',
#        'engenheiro de dados especialista',
#        'pessoa engenheira de dados - posicao destinada a pessoas com deficiencia',
#        'engenheiro de dados trainee (chapeco-sc)',
#        'engenheiro de dados (3193) ',
#        'engenheiro de suporte de dados - rj, sp e es    ',
#        'banco de talentos - engenheiro de dados  - engenheiro de aplicacao',
#        '[banco de talentos] pessoa engenheira de dados',
#        'engenheiro civil - banco de dados', 'engenheiro(a) de dados'],
#       dtype=object)

# %% [markdown]
# ## Localidade

# %%
df_vagas['cidade'] = df_vagas['local'].apply(lambda x: 'Não informado' if x == 'Não informado' else x.split(' - ')[0])
df_vagas['estado'] = df_vagas['local'].apply(lambda x: 'Não informado' if x == 'Não informado' else x.split(' - ')[1])

# %%
df_vagas['cidade']
# Out:
# 0           Curitiba
# 1          São Paulo
# 2             Maceió
# 3      Não informado
# 4      Não informado
#            ...
# 309        Fortaleza
# 310         Salvador
# 311    Poços de C...
# 312    Não informado
# 313        São Paulo
# Name: cidade, Length: 314, dtype: object

# %% [markdown]
# # Save Dataframe

# %%
columns_selected = [
            'site_da_vaga',
            'link_site',
            'link_origem',
            'data_publicacao',
            'data_coleta',
            'posicao',
            'titulo_da_vaga',
            'senioridade',
            'cidade',
            'estado',
            'modalidade',
            'nome_empresa',
            'contrato',
            'regime',
            'pcd',
            'beneficios',
            'codigo_vaga',
            'descricao',
            'data_expiracao'
]

# %%
df_vagas[columns_selected].to_excel('../data/data_clean/vagas_gupy_clean.xlsx', index=False)

# %%
df_vagas[columns_selected].head()
# Out:
#   site_da_vaga                                          link_site  \
# 0         Gupy  https://franquiasv4.gupy.io/job/eyJqb2JJZCI6Nj...
# 1         Gupy  https://neoassist.gupy.io/job/eyJqb2JJZCI6Njcx...
# 2         Gupy  https://mesha.gupy.io/job/eyJqb2JJZCI6NjcwOTgx...
# 3         Gupy  https://mesha.gupy.io/job/eyJqb2JJZCI6NjcwOTMz...
# 4         Gupy  https://vemserolxbrasil.gupy.io/job/eyJqb2JJZC...
#
#                                          link_origem data_publicacao  \
# 0  https://franquiasv4.gupy.io/job/eyJqb2JJZCI6Nj...      2024-02-03
# 1  https://neoassist.gupy.io/job/eyJqb2JJZCI6Njcx...      2024-02-02
# 2  https://mesha.gupy.io/job/eyJqb2JJZCI6NjcwOTgx...      2024-02-02
# 3  https://mesha.gupy.io/job/eyJqb2JJZCI6NjcwOTMz...      2024-02-02
# 4  https://vemserolxbrasil.gupy.io/job/eyJqb2JJZC...      2024-02-02
#
#   data_coleta            posicao  \
# 0  2024-02-05  Analista de Dados
# 1  2024-02-05  Analista de Dados
# 2  2024-02-05  Analista de Dados
# 3  2024-02-05  Analista de Dados
# 4  2024-02-05  Analista de Dados
#
#                                       titulo_da_vaga    senioridade  \
# 0   Analista de Dados - Junior/Pleno | V4 Jasson ...   Júnior/Pleno
# 1                            Analista de Dados Pleno          Pleno
# 2  Analista de Dados - Trainne (Presencial - Maceió)  Não informado
# 3                         Analista de Dados - Remota  Não informado
# 4                            Analista de Dados Pleno          Pleno
#
#           cidade         estado  modalidade         nome_empresa  \
# 0       Curitiba             PR     Híbrido  Unidades V4 Company
# 1      São Paulo             SP     Híbrido            NeoAssist
# 2         Maceió             AL  Presencial     MESHA TECNOLOGIA
# 3  Não informado  Não informado      Remoto     MESHA TECNOLOGIA
# 4  Não informado  Não informado      Remoto            Grupo OLX
#
#           contrato  regime  pcd  beneficios  codigo_vaga  \
# 0  Pessoa Jurídica     NaN  Sim         NaN    6711345.0
# 1          Efetivo     NaN  Sim         NaN    6710537.0
# 2          Efetivo     NaN  Sim         NaN    6709810.0
# 3          Efetivo     NaN  Sim         NaN    6709335.0
# 4          Efetivo     NaN  Sim         NaN    6609585.0
#
#                                            descricao data_expiracao
# 0  Descrição da vagaVenha se juntar com a gente n...     2024-03-01
# 1  Descrição da vagaA Neo está buscando uma pesso...     2024-04-01
# 2  Descrição da vagaCom mais de 12 anos no mercad...     2024-04-30
# 3  Descrição da vagaCom mais de 12 anos no mercad...     2024-03-31
# 4  Descrição da vagaQuer fazer parte de uma das m...     2024-03-18
